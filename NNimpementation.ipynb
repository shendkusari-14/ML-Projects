# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
import itertools
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %%
def initialize_weights(nodes):
    """Initialize weights with random values in [-1, 1] (including bias)"""
    layers, weights = len(nodes), []
     
    
    for i in range(1, layers):
        w = [[np.random.uniform(-1, 1) for k in range(nodes[i-1] + 1)]
              for j in range(nodes[i])]
        weights.append(np.matrix(w))
    
    return weights

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return np.multiply(x, 1 - x)

def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return np.where(x > 0, 1, 0)

# %%
def forward_propagation(x, weights, layers, activation_function):
    activations, layer_input = [x], x
    for j in range(layers):
        if activation_function == 'sigmoid':
            activation_result = sigmoid(np.dot(layer_input, weights[j].T))
        elif activation_function == 'relu':
            activation_result = relu(np.dot(layer_input, weights[j].T))
       
        else:
            raise ValueError(f"Unsupported activation function: {activation_function}")

        activations.append(activation_result)
        layer_input = np.append(1, activation_result)  # Augment with bias

    return activations

# %%
def back_propagation(y, activations, weights, layers, lr,function_derivate):
    outputFinal = activations[-1]
    error = np.matrix(y - outputFinal) # Error at output
    
    for j in range(layers, 0, -1):
        currActivation = activations[j]
        
        if(j > 1):
            # Augment previous activation
            prevActivation = np.append(1, activations[j-1])
        else:
            # First hidden layer, prevActivation is input (without bias)
            prevActivation = activations[0]
        
        delta = np.multiply(error, function_derivate(currActivation))
        weights[j-1] += lr * np.multiply(delta.T, prevActivation)

        w = np.delete(weights[j-1], [0], axis=1) # Remove bias from weights
        error = np.dot(delta, w) # Calculate error for current layer
    
    return weights

# %%
def train(X, Y, lr, weights,activation_function):
    layers = len(weights)
    for i in range(len(X)):
        x, y = X[i], Y[i]
        x = np.matrix(np.append(1, x)) # Augment feature vector
        activations = forward_propagation(x, weights, layers,activation_function)
        if activation_function == 'sigmoid':

            weights = back_propagation(y, activations, weights, layers, lr,sigmoid_derivative)
       
        else:
            weights = back_propagation(y, activations, weights, layers, lr,relu_derivative)
       



            

    return weights

# %%
def predict(item, weights, activation_function):
    layers = len(weights)
    item = np.append(np.ones(1), item)  # Augment feature vector
    activations = forward_propagation(item, weights,layers, activation_function)
    output_final = activations[-1].A1
    index = np.argmax(output_final)

    y = np.zeros(len(output_final))
    y[index] = 1

    return y

# %%
def accuracy(X, Y, weights, activation_function):
    correct = 0

    for i in range(len(X)):
        x, y = X[i], Y[i]
        guess = predict(x, weights, activation_function)

        if np.array_equal(y, guess):
            correct += 1

    return correct / len(X)

# %%
import itertools

def grid_search(X_train, Y_train, X_test, Y_test, activation_functions, learning_rates):
    f = len(X_train[0])  # Number of features
    o = len(Y_train[0])  # Number of outputs / classes

    min_layers = 2
    max_layers = 4
    min_nodes = 3
    max_nodes = 5
    scores = {}

    best_accuracy = 0
    best_params = {}

    for activation_function in activation_functions:
        for num_layers in range(min_layers, max_layers+1):
            nodes_range = range(min_nodes, max_nodes + 1)
            layer_combinations = itertools.product(nodes_range, repeat=num_layers - 1)

            for combination in layer_combinations:
                for lr in learning_rates:  # Iterate over learning rates
                    layers = [f] + list(combination) + [o]
                    print(f"Configuration: {layers}, Learning Rate: {lr}")

                    epochs = 100
                    weights = initialize_weights(layers)

                    for _ in range(epochs):
                        weights = train(X_train, Y_train, lr, weights, activation_function)

                    score = accuracy(X_test, Y_test, weights, activation_function)
                    layers_tuple = tuple(layers)
                    scores[layers_tuple + (lr,)] = {'activation_function': activation_function, 'score': score}
                    print(f"Testing Accuracy with {activation_function} and Learning Rate {lr}: {score}")
                    print("--------------------------------------------")

                    # Update best parameters if accuracy is improved
                    if score > best_accuracy:
                        best_accuracy = score
                        best_params = {
                            'activation_function': activation_function,
                            'layers': layers,
                            'learning_rate': lr,
                            'epochs': epochs,
                            'weights': weights
                        }

    print(f"Best Configuration: {best_params['layers']} with {best_params['activation_function']} activation function and Learning Rate {best_params['learning_rate']}")
    return best_params, best_accuracy

# %%
from sklearn.model_selection import KFold
import itertools

def grid_search_cv(X, Y, activation_functions, learning_rates, num_folds=5):
    f = len(X[0])  # Number of features
    o = len(Y[0])  # Number of outputs / classes

    min_layers = 2
    max_layers = 4
    min_nodes = 3
    max_nodes = 5
    scores = {}

    best_accuracy = 0
    best_params = {}

    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    for activation_function in activation_functions:
        for num_layers in range(min_layers, max_layers + 1):
            nodes_range = range(min_nodes, max_nodes + 1)
            layer_combinations = itertools.product(nodes_range, repeat=num_layers - 1)

            for combination in layer_combinations:
                for lr in learning_rates:
                    layers = [f] + list(combination) + [o]
                    print(f"Configuration: {layers}, Learning Rate: {lr}")

                    total_accuracy = 0

                    for train_idx, test_idx in kf.split(X):
                        X_train, X_val = X[train_idx], X[test_idx]
                        Y_train, Y_val = Y[train_idx], Y[test_idx]

                        epochs = 100
                        weights = initialize_weights(layers)

                        for _ in range(epochs):
                            weights = train(X_train, Y_train, lr, weights, activation_function)

                        # Calculate accuracy using a different variable name
                        acc = accuracy(X_val, Y_val, weights, activation_function)
                        total_accuracy += acc

                    avg_accuracy = total_accuracy / num_folds
                    layers_tuple = tuple(layers)
                    scores[layers_tuple + (lr,)] = {'activation_function': activation_function, 'score': avg_accuracy}
                    print(f"Cross-validated Accuracy with {activation_function} and Learning Rate {lr}: {avg_accuracy}")
                    print("--------------------------------------------")

                    # Update best parameters if accuracy is improved
                    if avg_accuracy > best_accuracy:
                        best_accuracy = avg_accuracy
                        best_params = {
                            'activation_function': activation_function,
                            'layers': layers,
                            'learning_rate': lr,
                            'epochs': epochs,
                            'weights': weights
                        }

    print(f"Best Configuration: {best_params['layers']} with {best_params['activation_function']} activation function and Learning Rate {best_params['learning_rate']}")
    return best_params, best_accuracy

# %%
def predict_with_params(item, best_params):
    weights = best_params['weights']
    activation_function = best_params['activation_function']

    layers = len(weights)
    item = np.append(np.ones(1), item)  # Augment feature vector
    activations = forward_propagation(item, weights, layers, activation_function)
    output_final = activations[-1].A1
    index = np.argmax(output_final)

    y = np.zeros(len(output_final))
    y[index] = 1

    return y

# %%
def run_with_best_params(X_test, best_params):
    predictions = []
    for item in X_test:
        prediction = predict_with_params(item, best_params)
        predictions.append(prediction)

    return predictions

# %%
df = pd.read_csv("./data/breast_cancer/breast-cancer-diagnostic.shuf.lrn.csv", skipinitialspace=True)

# %%
y = df['class']
y=pd.DataFrame(y)
df = df.drop(['class', "ID"], axis=1)
df = np.array(df)

# %%
from sklearn.preprocessing import OneHotEncoder

y['class'] = y['class'].astype(str)
y['class'] = y['class'].map({'False': 0, 'True': 1})
one_hot_encoder = OneHotEncoder(sparse=False)
y = one_hot_encoder.fit_transform(np.array(y).reshape(-1, 1))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split

# Split into train and temp (which includes validation and test)
X_train, X_temp, Y_train, Y_temp = train_test_split(df, y, test_size=0.2, random_state=42)

# Split temp into validation and test
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %%
import time

# Record the start time
start_time = time.time()



activation_functions = ['sigmoid','relu']
learning_rates = [0.1, 0.01, 0.001]

best_params,best_accuracy = grid_search_cv(X_train, Y_train, activation_functions,learning_rates)



end_time = time.time()
# Out:
# Configuration: [30, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9605797101449276
# --------------------------------------------
# Configuration: [30, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9778743961352656
# --------------------------------------------
# Configuration: [30, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.7769082125603864
# --------------------------------------------
# Configuration: [30, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9735265700483092
# --------------------------------------------
# Configuration: [30, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9866666666666667
# --------------------------------------------
# Configuration: [30, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.8856038647342995
# --------------------------------------------
# Configuration: [30, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.8855072463768117
# --------------------------------------------
# Configuration: [30, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9648309178743961
# --------------------------------------------
# Configuration: [30, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9560386473429953
# --------------------------------------------
# Configuration: [30, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.956135265700483
# --------------------------------------------
# Configuration: [30, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9691787439613527
# --------------------------------------------
# Configuration: [30, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9604830917874396
# --------------------------------------------
# Configuration: [30, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9735265700483092
# --------------------------------------------
# Configuration: [30, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9469565217391305
# --------------------------------------------
# Configuration: [30, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9649275362318841
# --------------------------------------------
# Configuration: [30, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9602898550724639
# --------------------------------------------
# Configuration: [30, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6268599033816425
# --------------------------------------------
# Configuration: [30, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.8846376811594203
# --------------------------------------------
# Configuration: [30, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6183574879227052
# --------------------------------------------
# Configuration: [30, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9604830917874396
# --------------------------------------------
# Configuration: [30, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9690821256038648
# --------------------------------------------
# Configuration: [30, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9561352657004832
# --------------------------------------------
# Configuration: [30, 3, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 3, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.648599033816425
# --------------------------------------------
# Configuration: [30, 3, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 3, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7108212560386473
# --------------------------------------------
# Configuration: [30, 3, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 3, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6616425120772946
# --------------------------------------------
# Configuration: [30, 3, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9604830917874396
# --------------------------------------------
# Configuration: [30, 3, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6627053140096618
# --------------------------------------------
# Configuration: [30, 3, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9649275362318841
# --------------------------------------------
# Configuration: [30, 3, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6746859903381642
# --------------------------------------------
# Configuration: [30, 3, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 3, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 3, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6790338164251207
# --------------------------------------------
# Configuration: [30, 3, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 3, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6616425120772946
# --------------------------------------------
# Configuration: [30, 3, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 4, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9648309178743961
# --------------------------------------------
# Configuration: [30, 4, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6716908212560386
# --------------------------------------------
# Configuration: [30, 4, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 4, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7007729468599033
# --------------------------------------------
# Configuration: [30, 4, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9692753623188406
# --------------------------------------------
# Configuration: [30, 4, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9735265700483092
# --------------------------------------------
# Configuration: [30, 4, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6529468599033816
# --------------------------------------------
# Configuration: [30, 4, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9604830917874396
# --------------------------------------------
# Configuration: [30, 4, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.9256038647342996
# --------------------------------------------
# Configuration: [30, 4, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 4, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7456038647342995
# --------------------------------------------
# Configuration: [30, 4, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 4, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6659903381642512
# --------------------------------------------
# Configuration: [30, 4, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9649275362318841
# --------------------------------------------
# Configuration: [30, 4, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.8007729468599034
# --------------------------------------------
# Configuration: [30, 4, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 5, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 5, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7147826086956521
# --------------------------------------------
# Configuration: [30, 5, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9517874396135266
# --------------------------------------------
# Configuration: [30, 5, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7007729468599033
# --------------------------------------------
# Configuration: [30, 5, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 5, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7588405797101448
# --------------------------------------------
# Configuration: [30, 5, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 5, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7845410628019324
# --------------------------------------------
# Configuration: [30, 5, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9779710144927536
# --------------------------------------------
# Configuration: [30, 5, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7833816425120772
# --------------------------------------------
# Configuration: [30, 5, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 5, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.7833816425120772
# --------------------------------------------
# Configuration: [30, 5, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9736231884057972
# --------------------------------------------
# Configuration: [30, 5, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.8080193236714976
# --------------------------------------------
# Configuration: [30, 5, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with sigmoid and Learning Rate 0.1: 0.9649275362318841
# --------------------------------------------
# Configuration: [30, 5, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with sigmoid and Learning Rate 0.01: 0.8209661835748792
# --------------------------------------------
# Configuration: [30, 5, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with sigmoid and Learning Rate 0.001: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.7415458937198067
# --------------------------------------------
# Configuration: [30, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6583574879227052
# --------------------------------------------
# Configuration: [30, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7233816425120774
# --------------------------------------------
# Configuration: [30, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6095652173913043
# --------------------------------------------
# Configuration: [30, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8079227053140098
# --------------------------------------------
# Configuration: [30, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.841256038647343
# --------------------------------------------
# Configuration: [30, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6007729468599033
# --------------------------------------------
# Configuration: [30, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7546859903381643
# --------------------------------------------
# Configuration: [30, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8242512077294686
# --------------------------------------------
# Configuration: [30, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7096618357487923
# --------------------------------------------
# Configuration: [30, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.6601932367149759
# --------------------------------------------
# Configuration: [30, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6920772946859903
# --------------------------------------------
# Configuration: [30, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8772946859903381
# --------------------------------------------
# Configuration: [30, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7833816425120772
# --------------------------------------------
# Configuration: [30, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6616425120772946
# --------------------------------------------
# Configuration: [30, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6790338164251207
# --------------------------------------------
# Configuration: [30, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7345893719806764
# --------------------------------------------
# Configuration: [30, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6398067632850242
# --------------------------------------------
# Configuration: [30, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6139130434782608
# --------------------------------------------
# Configuration: [30, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.6746859903381642
# --------------------------------------------
# Configuration: [30, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7294685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8057004830917874
# --------------------------------------------
# Configuration: [30, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7560386473429952
# --------------------------------------------
# Configuration: [30, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8021256038647344
# --------------------------------------------
# Configuration: [30, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6746859903381642
# --------------------------------------------
# Configuration: [30, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8339130434782609
# --------------------------------------------
# Configuration: [30, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7542995169082125
# --------------------------------------------
# Configuration: [30, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8631884057971014
# --------------------------------------------
# Configuration: [30, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6181642512077294
# --------------------------------------------
# Configuration: [30, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7369082125603865
# --------------------------------------------
# Configuration: [30, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8598067632850241
# --------------------------------------------
# Configuration: [30, 3, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7681159420289856
# --------------------------------------------
# Configuration: [30, 3, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8250241545893721
# --------------------------------------------
# Configuration: [30, 3, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7460869565217392
# --------------------------------------------
# Configuration: [30, 3, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.6352657004830917
# --------------------------------------------
# Configuration: [30, 3, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7455072463768115
# --------------------------------------------
# Configuration: [30, 3, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7278260869565216
# --------------------------------------------
# Configuration: [30, 3, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6616425120772946
# --------------------------------------------
# Configuration: [30, 3, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7483091787439613
# --------------------------------------------
# Configuration: [30, 3, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.812657004830918
# --------------------------------------------
# Configuration: [30, 3, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8542028985507246
# --------------------------------------------
# Configuration: [30, 3, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8068599033816424
# --------------------------------------------
# Configuration: [30, 3, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8120772946859903
# --------------------------------------------
# Configuration: [30, 3, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.5659903381642513
# --------------------------------------------
# Configuration: [30, 3, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.5572946859903382
# --------------------------------------------
# Configuration: [30, 3, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7186473429951691
# --------------------------------------------
# Configuration: [30, 3, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 3, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.6795169082125604
# --------------------------------------------
# Configuration: [30, 3, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6790338164251207
# --------------------------------------------
# Configuration: [30, 3, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7367149758454106
# --------------------------------------------
# Configuration: [30, 3, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8778743961352659
# --------------------------------------------
# Configuration: [30, 4, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.739903381642512
# --------------------------------------------
# Configuration: [30, 4, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.5428019323671498
# --------------------------------------------
# Configuration: [30, 4, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7355555555555555
# --------------------------------------------
# Configuration: [30, 4, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7051207729468598
# --------------------------------------------
# Configuration: [30, 4, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.741159420289855
# --------------------------------------------
# Configuration: [30, 4, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.6808695652173913
# --------------------------------------------
# Configuration: [30, 4, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.5920772946859902
# --------------------------------------------
# Configuration: [30, 4, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.5917874396135265
# --------------------------------------------
# Configuration: [30, 4, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7529468599033816
# --------------------------------------------
# Configuration: [30, 4, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.643768115942029
# --------------------------------------------
# Configuration: [30, 4, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7418357487922705
# --------------------------------------------
# Configuration: [30, 4, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.753816425120773
# --------------------------------------------
# Configuration: [30, 4, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6877294685990337
# --------------------------------------------
# Configuration: [30, 4, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7659903381642512
# --------------------------------------------
# Configuration: [30, 4, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8324637681159419
# --------------------------------------------
# Configuration: [30, 4, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7365217391304347
# --------------------------------------------
# Configuration: [30, 4, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 4, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8020289855072464
# --------------------------------------------
# Configuration: [30, 4, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.82512077294686
# --------------------------------------------
# Configuration: [30, 5, 3, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8155555555555555
# --------------------------------------------
# Configuration: [30, 5, 3, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.6879227053140097
# --------------------------------------------
# Configuration: [30, 5, 3, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 3, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6672463768115942
# --------------------------------------------
# Configuration: [30, 5, 3, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.759903381642512
# --------------------------------------------
# Configuration: [30, 5, 3, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.5094685990338164
# --------------------------------------------
# Configuration: [30, 5, 3, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8240579710144929
# --------------------------------------------
# Configuration: [30, 5, 3, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7103381642512077
# --------------------------------------------
# Configuration: [30, 5, 4, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.5964251207729468
# --------------------------------------------
# Configuration: [30, 5, 4, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.8064734299516909
# --------------------------------------------
# Configuration: [30, 5, 4, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.669951690821256
# --------------------------------------------
# Configuration: [30, 5, 4, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6717874396135266
# --------------------------------------------
# Configuration: [30, 5, 4, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7283091787439614
# --------------------------------------------
# Configuration: [30, 5, 4, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 4, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7572946859903381
# --------------------------------------------
# Configuration: [30, 5, 4, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.8063768115942029
# --------------------------------------------
# Configuration: [30, 5, 5, 3, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 5, 3, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7678260869565218
# --------------------------------------------
# Configuration: [30, 5, 5, 3, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7993236714975844
# --------------------------------------------
# Configuration: [30, 5, 5, 4, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.7323671497584541
# --------------------------------------------
# Configuration: [30, 5, 5, 4, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.7572946859903381
# --------------------------------------------
# Configuration: [30, 5, 5, 4, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.739903381642512
# --------------------------------------------
# Configuration: [30, 5, 5, 5, 2], Learning Rate: 0.1
# Cross-validated Accuracy with relu and Learning Rate 0.1: 0.6094685990338163
# --------------------------------------------
# Configuration: [30, 5, 5, 5, 2], Learning Rate: 0.01
# Cross-validated Accuracy with relu and Learning Rate 0.01: 0.6877294685990337
# --------------------------------------------
# Configuration: [30, 5, 5, 5, 2], Learning Rate: 0.001
# Cross-validated Accuracy with relu and Learning Rate 0.001: 0.7208695652173913
# --------------------------------------------
# Best Configuration: [30, 4, 2] with sigmoid activation function and Learning Rate 0.01

# %%
best_params
#Configuration: [30, 3, 2]
# Out:
# ({'activation_function': 'sigmoid',
#   'layers': [30, 4, 2],
#   'learning_rate': 0.01,
#   'epochs': 100,
#   'weights': [matrix([[ 0.01663168, -0.5892001 ,  0.56665088,  0.14564999,  0.98954898,
#             -0.61810228, -0.37224761, -0.58487626,  0.66786147,  0.80976722,
#             -0.26983575,  1.10602579,  0.22466728, -0.64663712,  1.13633403,
#             -0.54753642,  0.3847689 ,  0.35121155, -0.53427436,  0.28642948,
#              0.03244976,  0.33658072,  0.38507615, -0.42231667,  0.555426  ,
#              1.0573559 ,  0.2478337 ,  0.22073142,  0.73314785, -0.72139655,
#             -0.35369127],
#            [-0.04062523, -0.52254543, -1.21055492, -0.77659463, -1.0430254 ,
#              0.5868272 ,  0.64013533,  0.43837203,  0.21259594, -1.10494935,
#              0.27555332, -1.09858487, -0.6242303 , -0.55217228, -0.00233498,
#              0.96629532, -0.211672  , -0.29985052, -0.33805922,  0.25096185,
#              1.06988018, -0.78425186,  0.10720898, -0.970665  ,  0.07109118,
#             -1.31415017, -0.6656186 , -0.01003075, -0.619895  ,  0.17475541,
#             -0.74426178],
#            [-0.81407554, -1.01479756, -1.14949224,  0.2095948 , -0.1301162 ,
#             -0.82721289,  0.0823471 ,  0.87797349, -0.9251949 , -0.57370805,
#             -0.61742608,  0.37648261, -0.54720353,  0.19398309, -0.12139107,
#             -0.38934127,  0.32194882, -0.45236711, -0.27186419,  0.50744559,
#             -0.38847516,  0.2962237 ,  0.20864371, -1.11925217,  0.22300433,
#             -0.35811586, -0.05893613, -0.63166248, -0.09701364, -0.55520786,
#              0.09308174],
#            [-0.76253837, -0.06018142, -0.5537069 ,  0.30956574,  0.07427598,
#              0.81302958, -0.58595175, -0.49749377,  1.15031712, -0.40333485,
#             -0.96706188,  0.90862757, -0.50463221, -0.16382869,  1.10114062,
#              0.58247082, -0.85431265,  0.55733496, -0.57526949,  0.5801029 ,
#              0.22898048, -0.08861543,  0.49355826, -0.1784529 ,  1.25578637,
#              0.22001888,  0.92409966,  0.90755019,  1.25458309,  0.23372503,
#              0.59610928]]),
#    matrix([[ 0.36440372, -1.19749113,  2.17644521,  0.46790801, -1.76825466],
#            [ 0.34012531,  0.50829459, -2.53858308, -0.87973171,  1.63869803]])]},
#  0.9866666666666667)

# %%
# Calculate the elapsed time in seconds
elapsed_time_seconds = end_time - start_time

# Convert elapsed time to minutes
elapsed_time_minutes = elapsed_time_seconds / 60

# Print the elapsed time
print(f"Grid search CV took {elapsed_time_minutes} minutes")
# Out:
# Grid search CV took 121.48661988178888 minutes

# %% [markdown]
# Grid search took 30.024658981959025 minutes (without CV)

# %%
weights = best_params[0]['weights']
weights
# Out:
# [matrix([[ 0.01663168, -0.5892001 ,  0.56665088,  0.14564999,  0.98954898,
#           -0.61810228, -0.37224761, -0.58487626,  0.66786147,  0.80976722,
#           -0.26983575,  1.10602579,  0.22466728, -0.64663712,  1.13633403,
#           -0.54753642,  0.3847689 ,  0.35121155, -0.53427436,  0.28642948,
#            0.03244976,  0.33658072,  0.38507615, -0.42231667,  0.555426  ,
#            1.0573559 ,  0.2478337 ,  0.22073142,  0.73314785, -0.72139655,
#           -0.35369127],
#          [-0.04062523, -0.52254543, -1.21055492, -0.77659463, -1.0430254 ,
#            0.5868272 ,  0.64013533,  0.43837203,  0.21259594, -1.10494935,
#            0.27555332, -1.09858487, -0.6242303 , -0.55217228, -0.00233498,
#            0.96629532, -0.211672  , -0.29985052, -0.33805922,  0.25096185,
#            1.06988018, -0.78425186,  0.10720898, -0.970665  ,  0.07109118,
#           -1.31415017, -0.6656186 , -0.01003075, -0.619895  ,  0.17475541,
#           -0.74426178],
#          [-0.81407554, -1.01479756, -1.14949224,  0.2095948 , -0.1301162 ,
#           -0.82721289,  0.0823471 ,  0.87797349, -0.9251949 , -0.57370805,
#           -0.61742608,  0.37648261, -0.54720353,  0.19398309, -0.12139107,
#           -0.38934127,  0.32194882, -0.45236711, -0.27186419,  0.50744559,
#           -0.38847516,  0.2962237 ,  0.20864371, -1.11925217,  0.22300433,
#           -0.35811586, -0.05893613, -0.63166248, -0.09701364, -0.55520786,
#            0.09308174],
#          [-0.76253837, -0.06018142, -0.5537069 ,  0.30956574,  0.07427598,
#            0.81302958, -0.58595175, -0.49749377,  1.15031712, -0.40333485,
#           -0.96706188,  0.90862757, -0.50463221, -0.16382869,  1.10114062,
#            0.58247082, -0.85431265,  0.55733496, -0.57526949,  0.5801029 ,
#            0.22898048, -0.08861543,  0.49355826, -0.1784529 ,  1.25578637,
#            0.22001888,  0.92409966,  0.90755019,  1.25458309,  0.23372503,
#            0.59610928]]),
#  matrix([[ 0.36440372, -1.19749113,  2.17644521,  0.46790801, -1.76825466],
#          [ 0.34012531,  0.50829459, -2.53858308, -0.87973171,  1.63869803]])]

# %%
best_params
# Out:
# ({'activation_function': 'sigmoid',
#   'layers': [30, 4, 2],
#   'learning_rate': 0.01,
#   'epochs': 100,
#   'weights': [matrix([[ 0.01663168, -0.5892001 ,  0.56665088,  0.14564999,  0.98954898,
#             -0.61810228, -0.37224761, -0.58487626,  0.66786147,  0.80976722,
#             -0.26983575,  1.10602579,  0.22466728, -0.64663712,  1.13633403,
#             -0.54753642,  0.3847689 ,  0.35121155, -0.53427436,  0.28642948,
#              0.03244976,  0.33658072,  0.38507615, -0.42231667,  0.555426  ,
#              1.0573559 ,  0.2478337 ,  0.22073142,  0.73314785, -0.72139655,
#             -0.35369127],
#            [-0.04062523, -0.52254543, -1.21055492, -0.77659463, -1.0430254 ,
#              0.5868272 ,  0.64013533,  0.43837203,  0.21259594, -1.10494935,
#              0.27555332, -1.09858487, -0.6242303 , -0.55217228, -0.00233498,
#              0.96629532, -0.211672  , -0.29985052, -0.33805922,  0.25096185,
#              1.06988018, -0.78425186,  0.10720898, -0.970665  ,  0.07109118,
#             -1.31415017, -0.6656186 , -0.01003075, -0.619895  ,  0.17475541,
#             -0.74426178],
#            [-0.81407554, -1.01479756, -1.14949224,  0.2095948 , -0.1301162 ,
#             -0.82721289,  0.0823471 ,  0.87797349, -0.9251949 , -0.57370805,
#             -0.61742608,  0.37648261, -0.54720353,  0.19398309, -0.12139107,
#             -0.38934127,  0.32194882, -0.45236711, -0.27186419,  0.50744559,
#             -0.38847516,  0.2962237 ,  0.20864371, -1.11925217,  0.22300433,
#             -0.35811586, -0.05893613, -0.63166248, -0.09701364, -0.55520786,
#              0.09308174],
#            [-0.76253837, -0.06018142, -0.5537069 ,  0.30956574,  0.07427598,
#              0.81302958, -0.58595175, -0.49749377,  1.15031712, -0.40333485,
#             -0.96706188,  0.90862757, -0.50463221, -0.16382869,  1.10114062,
#              0.58247082, -0.85431265,  0.55733496, -0.57526949,  0.5801029 ,
#              0.22898048, -0.08861543,  0.49355826, -0.1784529 ,  1.25578637,
#              0.22001888,  0.92409966,  0.90755019,  1.25458309,  0.23372503,
#              0.59610928]]),
#    matrix([[ 0.36440372, -1.19749113,  2.17644521,  0.46790801, -1.76825466],
#            [ 0.34012531,  0.50829459, -2.53858308, -0.87973171,  1.63869803]])]},
#  0.9866666666666667)

# %%
predictions = []
best_params_dict = best_params[0]

for item in X_test:
    prediction = predict_with_params(item, best_params_dict)
    predictions.append(prediction)

# %%
# Calculate accuracy
accuracy = accuracy(X_test,Y_test,weights,'sigmoid')
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9310344827586207

# %%
mlp = MLPClassifier(hidden_layer_sizes=(4, 5), max_iter=500)  # 2 layers with 4 and 5 nodes
mlp.fit(X_train, Y_train)

# Evaluation
train_accuracy = mlp.score(X_train, Y_train)
test_accuracy = mlp.score(X_test, Y_test)

print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9868421052631579
# Test Accuracy: 0.9824561403508771
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
